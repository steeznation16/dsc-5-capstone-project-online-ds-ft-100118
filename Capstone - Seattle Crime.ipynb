# %% [markdown]
# # Capstone - Seattle Crime Data (June, 2009 - August, 2017)
#
# * Student name: Andrew Wester
# * Student pace: Full Time
# * Scheduled project review date/time: Thursday, March 28, 2019
# * Instructor name: Rafael Carrasco
# * Blog post URL:

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import folium
from folium import plugins
import os
import shutil
from IPython.display import Image, IFrame, display_html
from IPython.core.display import HTML 

import warnings
warnings.filterwarnings('ignore')

#!pip install jupyternotify
import jupyternotify
ip = get_ipython()
ip.register_magics(jupyternotify.JupyterNotifyMagics)
## Run %%notify to create notification for completed cell
# %notify

# %%
crime_df = pd.read_csv('Data/seattle_crime/Seattle_Police_Department_911_Incident_Response.csv')

# %%
crime_df.head()
# Out:
#   CAD CDW ID  CAD Event Number  General Offense Number  Event Clearance Code  \
# 0     ﻿15736       10000246357              2010246357                 242.0
# 1      15737       10000246471              2010246471                  65.0
# 2      15738       10000246255              2010246255                 250.0
# 3      15739       10000246473              2010246473                 460.0
# 4      15740       10000246330              2010246330                 250.0
#
#      Event Clearance Description       Event Clearance SubGroup  \
# 0              FIGHT DISTURBANCE                   DISTURBANCES
# 1          THEFT - MISCELLANEOUS                          THEFT
# 2  MISCHIEF, NUISANCE COMPLAINTS  NUISANCE, MISCHIEF COMPLAINTS
# 3     TRAFFIC (MOVING) VIOLATION          TRAFFIC RELATED CALLS
# 4  MISCHIEF, NUISANCE COMPLAINTS  NUISANCE, MISCHIEF COMPLAINTS
#
#    Event Clearance Group    Event Clearance Date  \
# 0           DISTURBANCES  07/17/2010 08:49:00 PM
# 1         OTHER PROPERTY  07/17/2010 08:50:00 PM
# 2    NUISANCE, MISCHIEF   07/17/2010 08:55:00 PM
# 3  TRAFFIC RELATED CALLS  07/17/2010 09:00:00 PM
# 4    NUISANCE, MISCHIEF   07/17/2010 09:00:00 PM
#
#               Hundred Block Location District/Sector Zone/Beat  Census Tract  \
# 0               3XX BLOCK OF PINE ST               M        M2     8100.2001
# 1  36XX BLOCK OF DISCOVERY PARK BLVD               Q        Q1     5700.1012
# 2              21XX BLOCK OF 3RD AVE               M        M2     7200.2025
# 3                7XX BLOCK OF ROY ST               D        D1     7200.1002
# 4              9XX BLOCK OF ALOHA ST               D        D1     6700.1009
#
#     Longitude   Latitude               Incident Location  \
# 0 -122.338147  47.610975  (47.610975163, -122.338146748)
# 1 -122.404613  47.658325  (47.658324899, -122.404612874)
# 2 -122.342843  47.613551  (47.613551471, -122.342843234)
# 3 -122.341847  47.625401  (47.625401388, -122.341846999)
# 4 -122.339709  47.627425  (47.627424837, -122.339708605)
#
#   Initial Type Description Initial Type Subgroup Initial Type Group  \
# 0                      NaN                   NaN                NaN
# 1                      NaN                   NaN                NaN
# 2                      NaN                   NaN                NaN
# 3                      NaN                   NaN                NaN
# 4                      NaN                   NaN                NaN
#
#   At Scene Time
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
crime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1433853 entries, 0 to 1433852
# Data columns (total 19 columns):
# CAD CDW ID                     1433853 non-null object
# CAD Event Number               1433853 non-null int64
# General Offense Number         1433853 non-null int64
# Event Clearance Code           1422435 non-null float64
# Event Clearance Description    1422434 non-null object
# Event Clearance SubGroup       1422434 non-null object
# Event Clearance Group          1422434 non-null object
# Event Clearance Date           1422269 non-null object
# Hundred Block Location         1430366 non-null object
# District/Sector                1432684 non-null object
# Zone/Beat                      1433852 non-null object
# Census Tract                   1431089 non-null float64
# Longitude                      1433852 non-null float64
# Latitude                       1433852 non-null float64
# Incident Location              1433852 non-null object
# Initial Type Description       856040 non-null object
# Initial Type Subgroup          856040 non-null object
# Initial Type Group             856040 non-null object
# At Scene Time                  410823 non-null object
# dtypes: float64(4), int64(2), object(13)
# memory usage: 207.8+ MB

# %% [markdown]
# ### Start Cleaning Data for Columns to be Dropped and Null Values

# %%
drops = crime_df.columns[15:]

# %%
crime_df.isna().sum()
# Out:
# CAD CDW ID                           0
# CAD Event Number                     0
# General Offense Number               0
# Event Clearance Code             11418
# Event Clearance Description      11419
# Event Clearance SubGroup         11419
# Event Clearance Group            11419
# Event Clearance Date             11584
# Hundred Block Location            3487
# District/Sector                   1169
# Zone/Beat                            1
# Census Tract                      2764
# Longitude                            1
# Latitude                             1
# Incident Location                    1
# Initial Type Description        577813
# Initial Type Subgroup           577813
# Initial Type Group              577813
# At Scene Time                  1023030
# dtype: int64

# %%
crime_df.drop(columns=drops, inplace=True)

# %%
crime_df.dropna(inplace=True)

# %%
# %%timeit
crime_df['Event Clearance Date'] = pd.to_datetime(crime_df['Event Clearance Date'])
# Out:
# 4.18 ms ± 253 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
crime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1415994 entries, 0 to 1433852
# Data columns (total 15 columns):
# CAD CDW ID                     1415994 non-null object
# CAD Event Number               1415994 non-null int64
# General Offense Number         1415994 non-null int64
# Event Clearance Code           1415994 non-null float64
# Event Clearance Description    1415994 non-null object
# Event Clearance SubGroup       1415994 non-null object
# Event Clearance Group          1415994 non-null object
# Event Clearance Date           1415994 non-null datetime64[ns]
# Hundred Block Location         1415994 non-null object
# District/Sector                1415994 non-null object
# Zone/Beat                      1415994 non-null object
# Census Tract                   1415994 non-null float64
# Longitude                      1415994 non-null float64
# Latitude                       1415994 non-null float64
# Incident Location              1415994 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(8)
# memory usage: 172.9+ MB

# %%
crime_df['Event Clearance Date'].describe()
# Out:
# count                 1415994
# unique                1186168
# top       2015-07-11 21:41:00
# freq                       12
# first     2009-06-17 16:14:00
# last      2017-08-29 11:44:01
# Name: Event Clearance Date, dtype: object

# %%
crime_groups = list(crime_df['Event Clearance Group'].unique())
print("There are", len(crime_groups), "different types of Crime in Seattle")
districts = crime_df['District/Sector'].unique()
print("There are", len(districts), "different Districts in Seattle")
print("There are", len(crime_df), "total Crimes committed in Seattle")
# Out:
# There are 44 different types of Crime in Seattle
# There are 19 different Districts in Seattle
# There are 1415994 total Crimes committed in Seattle

# %%
districts
# Out:
# array(['M', 'Q', 'D', 'R', 'U', 'K', 'N', 'S', 'F', 'J', 'L', 'W', 'E',
#        'C', 'G', 'B', 'O', '99', 'H'], dtype=object)

# %%
tops = crime_df[crime_df['District/Sector'] == 'M']['Event Clearance Group'].value_counts().nlargest(5).to_dict()
tops
# Out:
# {'DISTURBANCES': 18727,
#  'TRAFFIC RELATED CALLS': 14931,
#  'LIQUOR VIOLATIONS': 14550,
#  'SUSPICIOUS CIRCUMSTANCES': 11743,
#  'SHOPLIFTING': 8029}

# %%
for key in tops.keys():
    total = len(crime_df[crime_df['District/Sector'] == 'M'])
    percent = round((tops[key] / total)*100, 3)
    print(percent)
# Out:
# 14.62
# 11.656
# 11.359
# 9.168
# 6.268

# %%
crimes_dict = {}
for district in districts:
    df = crime_df[crime_df['District/Sector'] == district]
    total = len(df)
    crimes_dict[district] = {}
    top_5 = df['Event Clearance Group'].value_counts().nlargest(5).to_dict()
    crimes_dict[district]["top_5"] = ""
    for key in top_5.keys():
        percent = round((top_5[key] / total)*100, 3)
        crimes_dict[district]["top_5"] += "{} = {} percent of Crime, ".format(
            key.title(), percent)
#         crimes_dict[district]["top_5"] += "\n"

# %%
crimes_dict
# Out:
# {'M': {'top_5': 'Disturbances = 14.62 percent of Crime, Traffic Related Calls = 11.656 percent of Crime, Liquor Violations = 11.359 percent of Crime, Suspicious Circumstances = 9.168 percent of Crime, Shoplifting = 6.268 percent of Crime, '},
#  'Q': {'top_5': 'Traffic Related Calls = 21.557 percent of Crime, Suspicious Circumstances = 14.751 percent of Crime, Disturbances = 11.935 percent of Crime, Car Prowl = 4.642 percent of Crime, False Alarms = 4.214 percent of Crime, '},
#  'D': {'top_5': 'Traffic Related Calls = 17.376 percent of Crime, Disturbances = 13.992 percent of Crime, Suspicious Circumstances = 12.059 percent of Crime, Liquor Violations = 5.786 percent of Crime, Car Prowl = 4.686 percent of Crime, '},
#  'R': {'top_5': 'Traffic Related Calls = 21.72 percent of Crime, Suspicious Circumstances = 18.362 percent of Crime, Disturbances = 11.712 percent of Crime, False Alarms = 4.243 percent of Crime, Motor Vehicle Collision Investigation = 3.864 percent of Crime, '},
#  'U': {'top_5': 'Disturbances = 17.26 percent of Crime, Suspicious Circumstances = 16.625 percent of Crime, Traffic Related Calls = 15.218 percent of Crime, Burglary = 4.483 percent of Crime, Car Prowl = 3.664 percent of Crime, '},
#  'K': {'top_5': 'Liquor Violations = 21.465 percent of Crime, Disturbances = 13.383 percent of Crime, Traffic Related Calls = 12.122 percent of Crime, Suspicious Circumstances = 8.872 percent of Crime, Narcotics Complaints = 4.608 percent of Crime, '},
#  'N': {'top_5': 'Suspicious Circumstances = 20.074 percent of Crime, Traffic Related Calls = 14.838 percent of Crime, Disturbances = 13.728 percent of Crime, Other Property = 3.4 percent of Crime, Car Prowl = 3.384 percent of Crime, '},
#  'S': {'top_5': 'Traffic Related Calls = 20.327 percent of Crime, Suspicious Circumstances = 18.863 percent of Crime, Disturbances = 13.249 percent of Crime, Auto Thefts = 3.768 percent of Crime, Burglary = 3.652 percent of Crime, '},
#  'F': {'top_5': 'Suspicious Circumstances = 20.41 percent of Crime, Disturbances = 15.936 percent of Crime, Traffic Related Calls = 15.014 percent of Crime, Auto Thefts = 3.811 percent of Crime, Burglary = 3.57 percent of Crime, '},
#  'J': {'top_5': 'Traffic Related Calls = 22.629 percent of Crime, Suspicious Circumstances = 17.553 percent of Crime, Disturbances = 12.523 percent of Crime, Car Prowl = 4.673 percent of Crime, Burglary = 3.762 percent of Crime, '},
#  'L': {'top_5': 'Suspicious Circumstances = 19.72 percent of Crime, Disturbances = 14.93 percent of Crime, Traffic Related Calls = 14.315 percent of Crime, False Alarms = 4.436 percent of Crime, Burglary = 4.288 percent of Crime, '},
#  'W': {'top_5': 'Traffic Related Calls = 21.519 percent of Crime, Suspicious Circumstances = 17.574 percent of Crime, Disturbances = 13.085 percent of Crime, False Alarms = 4.564 percent of Crime, Burglary = 3.459 percent of Crime, '},
#  'E': {'top_5': 'Traffic Related Calls = 18.071 percent of Crime, Disturbances = 16.62 percent of Crime, Suspicious Circumstances = 13.803 percent of Crime, Liquor Violations = 8.374 percent of Crime, Trespass = 5.999 percent of Crime, '},
#  'C': {'top_5': 'Traffic Related Calls = 23.447 percent of Crime, Suspicious Circumstances = 16.635 percent of Crime, Disturbances = 12.725 percent of Crime, False Alarms = 4.687 percent of Crime, Car Prowl = 3.568 percent of Crime, '},
#  'G': {'top_5': 'Traffic Related Calls = 21.113 percent of Crime, Suspicious Circumstances = 15.697 percent of Crime, Disturbances = 15.158 percent of Crime, Shoplifting = 4.435 percent of Crime, Car Prowl = 3.363 percent of Crime, '},
#  'B': {'top_5': 'Traffic Related Calls = 19.736 percent of Crime, Suspicious Circumstances = 18.252 percent of Crime, Disturbances = 13.883 percent of Crime, Burglary = 3.932 percent of Crime, Car Prowl = 3.724 percent of Crime, '},
#  'O': {'top_5': 'Traffic Related Calls = 24.335 percent of Crime, Suspicious Circumstances = 13.996 percent of Crime, Disturbances = 9.413 percent of Crime, Liquor Violations = 8.027 percent of Crime, Accident Investigation = 4.188 percent of Crime, '},
#  '99': {'top_5': 'Traffic Related Calls = 51.887 percent of Crime, Suspicious Circumstances = 9.434 percent of Crime, Arrest = 5.66 percent of Crime, Disturbances = 5.66 percent of Crime, Person Down/Injury = 2.83 percent of Crime, '},
#  'H': {'top_5': 'Harbor Calls = 55.556 percent of Crime, Traffic Related Calls = 22.222 percent of Crime, Property Damage = 11.111 percent of Crime, Person Down/Injury = 11.111 percent of Crime, '}}

# %%
for key in crimes_dict.keys():
    items = (list(crimes_dict[key].values()))
    string = ()
    for i in items:
        print(i)
# Out:
# Disturbances = 14.62 percent of Crime, Traffic Related Calls = 11.656 percent of Crime, Liquor Violations = 11.359 percent of Crime, Suspicious Circumstances = 9.168 percent of Crime, Shoplifting = 6.268 percent of Crime,
# Traffic Related Calls = 21.557 percent of Crime, Suspicious Circumstances = 14.751 percent of Crime, Disturbances = 11.935 percent of Crime, Car Prowl = 4.642 percent of Crime, False Alarms = 4.214 percent of Crime,
# Traffic Related Calls = 17.376 percent of Crime, Disturbances = 13.992 percent of Crime, Suspicious Circumstances = 12.059 percent of Crime, Liquor Violations = 5.786 percent of Crime, Car Prowl = 4.686 percent of Crime,
# Traffic Related Calls = 21.72 percent of Crime, Suspicious Circumstances = 18.362 percent of Crime, Disturbances = 11.712 percent of Crime, False Alarms = 4.243 percent of Crime, Motor Vehicle Collision Investigation = 3.864 percent of Crime,
# Disturbances = 17.26 percent of Crime, Suspicious Circumstances = 16.625 percent of Crime, Traffic Related Calls = 15.218 percent of Crime, Burglary = 4.483 percent of Crime, Car Prowl = 3.664 percent of Crime,
# Liquor Violations = 21.465 percent of Crime, Disturbances = 13.383 percent of Crime, Traffic Related Calls = 12.122 percent of Crime, Suspicious Circumstances = 8.872 percent of Crime, Narcotics Complaints = 4.608 percent of Crime,
# Suspicious Circumstances = 20.074 percent of Crime, Traffic Related Calls = 14.838 percent of Crime, Disturbances = 13.728 percent of Crime, Other Property = 3.4 percent of Crime, Car Prowl = 3.384 percent of Crime,
# Traffic Related Calls = 20.327 percent of Crime, Suspicious Circumstances = 18.863 percent of Crime, Disturbances = 13.249 percent of Crime, Auto Thefts = 3.768 percent of Crime, Burglary = 3.652 percent of Crime,
# Suspicious Circumstances = 20.41 percent of Crime, Disturbances = 15.936 percent of Crime, Traffic Related Calls = 15.014 percent of Crime, Auto Thefts = 3.811 percent of Crime, Burglary = 3.57 percent of Crime,
# Traffic Related Calls = 22.629 percent of Crime, Suspicious Circumstances = 17.553 percent of Crime, Disturbances = 12.523 percent of Crime, Car Prowl = 4.673 percent of Crime, Burglary = 3.762 percent of Crime,
# Suspicious Circumstances = 19.72 percent of Crime, Disturbances = 14.93 percent of Crime, Traffic Related Calls = 14.315 percent of Crime, False Alarms = 4.436 percent of Crime, Burglary = 4.288 percent of Crime,
# Traffic Related Calls = 21.519 percent of Crime, Suspicious Circumstances = 17.574 percent of Crime, Disturbances = 13.085 percent of Crime, False Alarms = 4.564 percent of Crime, Burglary = 3.459 percent of Crime,
# Traffic Related Calls = 18.071 percent of Crime, Disturbances = 16.62 percent of Crime, Suspicious Circumstances = 13.803 percent of Crime, Liquor Violations = 8.374 percent of Crime, Trespass = 5.999 percent of Crime,
# Traffic Related Calls = 23.447 percent of Crime, Suspicious Circumstances = 16.635 percent of Crime, Disturbances = 12.725 percent of Crime, False Alarms = 4.687 percent of Crime, Car Prowl = 3.568 percent of Crime,
# Traffic Related Calls = 21.113 percent of Crime, Suspicious Circumstances = 15.697 percent of Crime, Disturbances = 15.158 percent of Crime, Shoplifting = 4.435 percent of Crime, Car Prowl = 3.363 percent of Crime,
# Traffic Related Calls = 19.736 percent of Crime, Suspicious Circumstances = 18.252 percent of Crime, Disturbances = 13.883 percent of Crime, Burglary = 3.932 percent of Crime, Car Prowl = 3.724 percent of Crime,
# Traffic Related Calls = 24.335 percent of Crime, Suspicious Circumstances = 13.996 percent of Crime, Disturbances = 9.413 percent of Crime, Liquor Violations = 8.027 percent of Crime, Accident Investigation = 4.188 percent of Crime,
# Traffic Related Calls = 51.887 percent of Crime, Suspicious Circumstances = 9.434 percent of Crime, Arrest = 5.66 percent of Crime, Disturbances = 5.66 percent of Crime, Person Down/Injury = 2.83 percent of Crime,
# Harbor Calls = 55.556 percent of Crime, Traffic Related Calls = 22.222 percent of Crime, Property Damage = 11.111 percent of Crime, Person Down/Injury = 11.111 percent of Crime,

# %%
detailed_crime_dict = {}
for district in districts:
    df = crime_df[crime_df['District/Sector'] == district]
    total = len(df)
    detailed_crime_dict["District {}".format(district)] = {}
    for crime in crime_groups:
        df1 = df[df['Event Clearance Group'] == crime]
        percent = round((len(df1) / total)*100, 3)
        detailed_crime_dict["District {}".format(district)][crime.capitalize()] = \
            "{} account for {} percent of Crime in District".format(crime.title(), percent, district)

# %%
detailed_crime_dict
# Out:
# {'District M': {'Disturbances': 'Disturbances account for 14.62 percent of Crime in District',
#   'Other property': 'Other Property account for 3.522 percent of Crime in District',
#   'Nuisance, mischief ': 'Nuisance, Mischief  account for 1.361 percent of Crime in District',
#   'Traffic related calls': 'Traffic Related Calls account for 11.656 percent of Crime in District',
#   'Suspicious circumstances': 'Suspicious Circumstances account for 9.168 percent of Crime in District',
#   'Mental health': 'Mental Health account for 1.413 percent of Crime in District',
#   'Liquor violations': 'Liquor Violations account for 11.359 percent of Crime in District',
#   'Trespass': 'Trespass account for 5.754 percent of Crime in District',
#   'Assaults': 'Assaults account for 2.264 percent of Crime in District',
#   'Narcotics complaints': 'Narcotics Complaints account for 5.8 percent of Crime in District',
#   'Accident investigation': 'Accident Investigation account for 1.842 percent of Crime in District',
#   'Shoplifting': 'Shoplifting account for 6.268 percent of Crime in District',
#   'Prowler': 'Prowler account for 0.121 percent of Crime in District',
#   'Burglary': 'Burglary account for 0.995 percent of Crime in District',
#   'Hazards': 'Hazards account for 0.799 percent of Crime in District',
#   'Property damage': 'Property Damage account for 1.083 percent of Crime in District',
#   'Car prowl': 'Car Prowl account for 3.925 percent of Crime in District',
#   'Bike': 'Bike account for 0.271 percent of Crime in District',
#   'Prostitution': 'Prostitution account for 0.057 percent of Crime in District',
#   'Miscellaneous misdemeanors': 'Miscellaneous Misdemeanors account for 0.987 percent of Crime in District',
#   'Animal complaints': 'Animal Complaints account for 0.132 percent of Crime in District',
#   'Threats, harassment': 'Threats, Harassment account for 0.801 percent of Crime in District',
#   'Person down/injury': 'Person Down/Injury account for 1.077 percent of Crime in District',
#   'Auto thefts': 'Auto Thefts account for 0.612 percent of Crime in District',
#   'Persons - lost, found, missing': 'Persons - Lost, Found, Missing account for 0.264 percent of Crime in District',
#   'False alarms': 'False Alarms account for 1.109 percent of Crime in District',
#   'Robbery': 'Robbery account for 0.658 percent of Crime in District',
#   'Arrest': 'Arrest account for 1.778 percent of Crime in District',
#   'False alacad': 'False Alacad account for 0.692 percent of Crime in District',
#   'Property - missing, found': 'Property - Missing, Found account for 0.916 percent of Crime in District',
#   'Reckless burning': 'Reckless Burning account for 0.006 percent of Crime in District',
#   'Behavioral health': 'Behavioral Health account for 0.764 percent of Crime in District',
#   'Weapons calls': 'Weapons Calls account for 0.301 percent of Crime in District',
#   'Nuisance, mischief': 'Nuisance, Mischief account for 5.094 percent of Crime in District',
#   'Lewd conduct': 'Lewd Conduct account for 0.305 percent of Crime in District',
#   'Fraud calls': 'Fraud Calls account for 0.738 percent of Crime in District',
#   'Harbor calls': 'Harbor Calls account for 0.016 percent of Crime in District',
#   'Motor vehicle collision investigation': 'Motor Vehicle Collision Investigation account for 1.341 percent of Crime in District',
#   'Drive by (no injury)': 'Drive By (No Injury) account for 0.004 percent of Crime in District',
#   'Other vice': 'Other Vice account for 0.034 percent of Crime in District',
#   'Failure to register (sex offender)': 'Failure To Register (Sex Offender) account for 0.011 percent of Crime in District',
#   'Homicide': 'Homicide account for 0.007 percent of Crime in District',
#   'Vice calls': 'Vice Calls account for 0.001 percent of Crime in District',
#   'Public gatherings': 'Public Gatherings account for 0.074 percent of Crime in District'},
#  'District Q': {'Disturbances': 'Disturbances account for 11.935 percent of Crime in District',
#   'Other property': 'Other Property account for 2.432 percent of Crime in District',
#   'Nuisance, mischief ': 'Nuisance, Mischief  account for 0.732 percent of Crime in District',
#   'Traffic related calls': 'Traffic Related Calls account for 21.557 percent of Crime in District',
#   'Suspicious circumstances': 'Suspicious Circumstances account for 14.751 percent of Crime in District',
#   'Mental health': 'Mental Health account for 1.001 percent of Crime in District',
#   'Liquor violations': 'Liquor Violations account for 3.53 percent of Crime in District',
#   'Trespass': 'Trespass account for 2.479 percent of Crime in District',
#   'Assaults': 'Assaults account for 1.117 percent of Crime in District',
#   'Narcotics complaints': 'Narcotics Complaints account for 0.627 percent of Crime in District',
#   'Accident investigation': 'Accident Investigation account for 2.633 percent of Crime in District',
#   'Shoplifting': 'Shoplifting account for 2.067 percent of Crime in District',
#   'Prowler': 'Prowler account for 0.201 percent of Crime in District',
#   'Burglary': 'Burglary account for 4.019 percent of Crime in District',
#   'Hazards': 'Hazards account for 1.79 percent of Crime in District',
#   'Property damage': 'Property Damage account for 1.971 percent of Crime in District',
#   'Car prowl': 'Car Prowl account for 4.642 percent of Crime in District',
#   'Bike': 'Bike account for 0.348 percent of Crime in District',
#   'Prostitution': 'Prostitution account for 0.02 percent of Crime in District',
#   'Miscellaneous misdemeanors': 'Miscellaneous Misdemeanors account for 0.384 percent of Crime in District',
#   'Animal complaints': 'Animal Complaints account for 0.31 percent of Crime in District',
#   'Threats, harassment': 'Threats, Harassment account for 0.898 percent of Crime in District',
#   'Person down/injury': 'Person Down/Injury account for 0.978 percent of Crime in District',
#   'Auto thefts': 'Auto Thefts account for 2.192 percent of Crime in District',
#   'Persons - lost, found, missing': 'Persons - Lost, Found, Missing account for 0.433 percent of Crime in District',
#   'False alarms': 'False Alarms account for 4.214 percent of Crime in District',
#   'Robbery': 'Robbery account for 0.275 percent of Crime in District',
#   'Arrest': 'Arrest account for 0.398 percent of Crime in District',
#   'False alacad': 'False Alacad account for 2.481 percent of Crime in District',
#   'Property - missing, found': 'Property - Missing, Found account for 1.005 percent of Crime in District',
#   'Reckless burning': 'Reckless Burning account for 0.023 percent of Crime in District',
#   'Behavioral health': 'Behavioral Health account for 0.749 percent of Crime in District',
#   'Weapons calls': 'Weapons Calls account for 0.148 percent of Crime in District',
#   'Nuisance, mischief': 'Nuisance, Mischief account for 2.493 percent of Crime in District',
#   'Lewd conduct': 'Lewd Conduct account for 0.217 percent of Crime in District',
#   'Fraud calls': 'Fraud Calls account for 1.443 percent of Crime in District',
#   'Harbor calls': 'Harbor Calls account for 0.124 percent of Crime in District',
#   'Motor vehicle collision investigation': 'Motor Vehicle Collision Investigation account for 3.318 percent of Crime in District',
#   'Drive by (no injury)': 'Drive By (No Injury) account for 0.003 percent of Crime in District',
#   'Other vice': 'Other Vice account for 0.009 percent of Crime in District',
#   'Failure to register (sex offender)': 'Failure To Register (Sex Offender) account for 0.009 percent of Crime in District',
#   'Homicide': 'Homicide account for 0.015 percent of Crime in District',
#   'Vice calls': 'Vice Calls account for 0.001 percent of Crime in District',
#   'Public gatherings': 'Public Gatherings account for 0.024 percent of Crime in District'},
#  'District D': {'Disturbances': 'Disturbances account for 13.992 percent of Crime in District',
#   'Other property': 'Other Property account for 3.505 percent of Crime in District',
#   'Nuisance, mischief ': 'Nuisance, Mischief  account for 1.583 percent of Crime in District',
#   'Traffic related calls': 'Traffic Related Calls account for 17.376 percent of Crime in District',
#   'Suspicious circumstances': 'Suspicious Circumstances account for 12.059 percent of Crime in District',
#   'Mental health': 'Mental Health account for 1.699 percent of Crime in District',
#   'Liquor violations': 'Liquor Violations account for 5.786 percent of Crime in District',
#   'Trespass': 'Trespass account for 4.375 percent of Crime in District',
#   'Assaults': 'Assaults account for 2.068 percent of Crime in District',
#   'Narcotics complaints': 'Narcotics Complaints account for 2.082 percent of Crime in District',
#   'Accident investigation': 'Accident Investigation account for 3.096 percent of Crime in District',
#   'Shoplifting': 'Shoplifting account for 1.601 percent of Crime in District',
#   'Prowler': 'Prowler account for 0.099 percent of Crime in District',
#   'Burglary': 'Burglary account for 2.549 percent of Crime in District',
#   'Hazards': 'Hazards account for 1.562 percent of Crime in District',
#   'Property damage': 'Property Damage account for 1.588 percent of Crime in District',
#   'Car prowl': 'Car Prowl account for 4.686 percent of Crime in District',
#   'Bike': 'Bike account for 0.458 percent of Crime in District',
#   'Prostitution': 'Prostitution account for 0.456 percent of Crime in District',
#   'Miscellaneous misdemeanors': 'Miscellaneous Misdemeanors account for 0.376 percent of Crime in District',
#   'Animal complaints': 'Animal Complaints account for 0.192 percent of Crime in District',
#   'Threats, harassment': 'Threats, Harassment account for 1.012 percent of Crime in District',
#   'Person down/injury': 'Person Down/Injury account for 0.989 percent of Crime in District',
#   'Auto thefts': 'Auto Thefts account for 1.485 percent of Crime in District',
#   'Persons - lost, found, missing': 'Persons - Lost, Found, Missing account for 0.472 percent of Crime in District',
#   'False alarms': 'False Alarms account for 1.618 percent of Crime in District',
#   'Robbery': 'Robbery account for 0.488 percent of Crime in District',
#   'Arrest': 'Arrest account for 1.182 percent of Crime in District',
#   'False alacad': 'False Alacad account for 1.204 percent of Crime in District',
#   'Property - missing, found': 'Property - Missing, Found account for 1.632 percent of Crime in District',
#   'Reckless burning': 'Reckless Burning account for 0.013 percent of Crime in District',
#   'Behavioral health': 'Behavioral Health account for 1.087 percent of Crime in District',
#   'Weapons calls': 'Weapons Calls account for 0.214 percent of Crime in District',
#   'Nuisance, mischief': 'Nuisance, Mischief account for 2.863 percent of Crime in District',
#   'Lewd conduct': 'Lewd Conduct account for 0.226 percent of Crime in District',
#   'Fraud calls': 'Fraud Calls account for 1.133 percent of Crime in District',
#   'Harbor calls': 'Harbor Calls account for 0.104 percent of Crime in District',
#   'Motor vehicle collision investigation': 'Motor Vehicle Collision Investigation account for 3.028 percent of Crime in District',
#   'Drive by (no injury)': 'Drive By (No Injury) account for 0.009 percent of Crime in District',
#   'Other vice': 'Other Vice account for 0.015 percent of Crime in District',
#   'Failure to register (sex offender)': 'Failure To Register (Sex Offender) account for 0.005 percent of Crime in District',
#   'Homicide': 'Homicide account for 0.015 percent of Crime in District',
#   'Vice calls': 'Vice Calls account for 0.0 percent of Crime in District',
#   'Public gatherings': 'Public Gatherings account for 0.02 percent of Crime in District'},
#  'District R': {'Disturbances': 'Disturbances account for 11.712 percent of Crime in District',
#   'Other property': 'Other Property account for 2.194 percent of Crime in District',
#   'Nuisance, mischief ': 'Nuisance, Mischief  account for 0.247 percent of Crime in District',
#   'Traffic related calls': 'Traffic Related Calls account for 21.72 percent of Crime in District',
#   'Suspicious circumstances': 'Suspicious Circumstances account for 18.362 percent of Crime in District',
#   'Mental health': 'Mental Health account for 0.882 percent of Crime in District',
#   'Liquor violations': 'Liquor Violations account for 3.047 percent of Crime in District',
#   'Trespass': 'Trespass account for 2.314 percent of Crime in District',
#   'Assaults': 'Assaults account for 1.296 percent of Crime in District',
#   'Narcotics complaints': 'Narcotics Complaints account for 0.999 percent of Crime in District',
#   'Accident investigation': 'Accident Investigation account for 3.003 percent of Crime in District',
#   'Shoplifting': 'Shoplifting account for 1.476 percent of Crime in District',
#   'Prowler': 'Prowler account for 0.128 percent of Crime in District',
#   'Burglary': 'Burglary account for 3.286 percent of Crime in District',
#   'Hazards': 'Hazards account for 1.303 percent of Crime in District',
#   'Property damage': 'Property Damage account for 1.753 percent of Crime in District',
#   'Car prowl': 'Car Prowl account for 3.508 percent of Crime in District',
#   'Bike': 'Bike account for 0.137 percent of Crime in District',
#   'Prostitution': 'Prostitution account for 0.134 percent of Crime in District',
#   'Miscellaneous misdemeanors': 'Miscellaneous Misdemeanors account for 0.214 percent of Crime in District',
#   'Animal complaints': 'Animal Complaints account for 0.321 percent of Crime in District',
#   'Threats, harassment': 'Threats, Harassment account for 1.02 percent of Crime in District',
#   'Person down/injury': 'Person Down/Injury account for 0.432 percent of Crime in District',
#   'Auto thefts': 'Auto Thefts account for 2.639 percent of Crime in District',
#   'Persons - lost, found, missing': 'Persons - Lost, Found, Missing account for 0.546 percent of Crime in District',
#   'False alarms': 'False Alarms account for 4.243 percent of Crime in District',
#   'Robbery': 'Robbery account for 0.83 percent of Crime in District',
#   'Arrest': 'Arrest account for 1.085 percent of Crime in District',
#   'False alacad': 'False Alacad account for 2.419 percent of Crime in District',
#   'Property - missing, found': 'Property - Missing, Found account for 0.822 percent of Crime in District',
#   'Reckless burning': 'Reckless Burning account for 0.013 percent of Crime in District',
#   'Behavioral health': 'Behavioral Health account for 0.693 percent of Crime in District',
#   'Weapons calls': 'Weapons Calls account for 0.377 percent of Crime in District',
#   'Nuisance, mischief': 'Nuisance, Mischief account for 1.176 percent of Crime in District',
#   'Lewd conduct': 'Lewd Conduct account for 0.178 percent of Crime in District',
#   'Fraud calls': 'Fraud Calls account for 1.092 percent of Crime in District',
#   'Harbor calls': 'Harbor Calls account for 0.146 percent of Crime in District',
#   'Motor vehicle collision investigation': 'Motor Vehicle Collision Investigation account for 3.864 percent of Crime in District',
#   'Drive by (no injury)': 'Drive By (No Injury) account for 0.223 percent of Crime in District',
#   'Other vice': 'Other Vice account for 0.025 percent of Crime in District',
#   'Failure to register (sex offender)': 'Failure To Register (Sex Offender) account for 0.097 percent of Crime in District',
#   'Homicide': 'Homicide account for 0.016 percent of Crime in District',
#   'Vice calls': 'Vice Calls account for 0.008 percent of Crime in District',
#   'Public gatherings': 'Public Gatherings account for 0.017 percent of Crime in District'},
#  'District U': {'Disturbances': 'Disturbances account for 17.26 percent of Crime in District',
#   'Other property': 'Other Property account for 2.712 percent of Crime in District',
#   'Nuisance, mischief ': 'Nuisance, Mischief  account for 0.575 percent of Crime in District',
#   'Traffic related calls': 'Traffic Related Calls account for 15.218 percent of Crime in District',
#   'Suspicious circumstances': 'Suspicious Circumstances account for 16.625 percent of Crime in District',
#   'Mental health': 'Mental Health account for 1.038 percent of Crime in District',
#   'Liquor violations': 'Liquor Violations account for 1.147 percent of Crime in District',
#   'Trespass': 'Trespass account for 3.005 percent of Crime in District',
#   'Assaults': 'Assaults account for 1.615 percent of Crime in District',
#   'Narcotics complaints': 'Narcotics Complaints account for 1.589 percent of Crime in District',
#   'Accident investigation': 'Accident Investigation account for 3.019 percent of Crime in District',
#   'Shoplifting': 'Shoplifting account for 3.054 percent of Crime in District',
#   'Prowler': 'Prowler account for 0.253 percent of Crime in District',
#   'Burglary': 'Burglary account for 4.483 percent of Crime in District',
#   'Hazards': 'Hazards account for 1.418 percent of Crime in District',
#   'Property damage': 'Property Damage account for 2.104 percent of Crime in District',
#   'Car prowl': 'Car Prowl account for 3.664 percent of Crime in District',
#   'Bike': 'Bike account for 0.513 percent of Crime in District',
#   'Prostitution': 'Prostitution account for 0.256 percent of Crime in District',
#   'Miscellaneous misdemeanors': 'Miscellaneous Misdemeanors account for 0.883 percent of Crime in District',
#   'Animal complaints': 'Animal Complaints account for 0.22 percent of Crime in District',
#   'Threats, harassment': 'Threats, Harassment account for 1.105 percent of Crime in District',
#   'Person down/injury': 'Person Down/Injury account for 0.5 percent of Crime in District',
#   'Auto thefts': 'Auto Thefts account for 2.643 percent of Crime in District',
#   'Persons - lost, found, missing': 'Persons - Lost, Found, Missing account for 0.319 percent of Crime in District',
#   'False alarms': 'False Alarms account for 2.552 percent of Crime in District',
#   'Robbery': 'Robbery account for 0.556 percent of Crime in District',
#   'Arrest': 'Arrest account for 0.83 percent of Crime in District',
#   'False alacad': 'False Alacad account for 2.044 percent of Crime in District',
#   'Property - missing, found': 'Property - Missing, Found account for 1.175 percent of Crime in District',
#   'Reckless burning': 'Reckless Burning account for 0.024 percent of Crime in District',
#   'Behavioral health': 'Behavioral Health account for 0.676 percent of Crime in District',
#   'Weapons calls': 'Weapons Calls account for 0.22 percent of Crime in District',
#   'Nuisance, mischief': 'Nuisance, Mischief account for 1.581 percent of Crime in District',
#   'Lewd conduct': 'Lewd Conduct account for 0.263 percent of Crime in District',
#   'Fraud calls': 'Fraud Calls account for 1.555 percent of Crime in District',
#   'Harbor calls': 'Harbor Calls account for 0.099 percent of Crime in District',
#   'Motor vehicle collision investigation': 'Motor Vehicle Collision Investigation account for 3.144 percent of Crime in District',
#   'Drive by (no injury)': 'Drive By (No Injury) account for 0.005 percent of Crime in District',
#   'Other vice': 'Other Vice account for 0.009 percent of Crime in District',
#   'Failure to register (sex offender)': 'Failure To Register (Sex Offender) account for 0.007 percent of Crime in District',
#   'Homicide': 'Homicide account for 0.018 percent of Crime in District',
#   'Vice calls': 'Vice Calls account for 0.005 percent of Crime in District',
#   'Public gatherings': 'Public Gatherings account for 0.023 percent of Crime in District'},
#  'District K': {'Disturbances': 'Disturbances account for 13.383 percent of Crime in District',
#   'Other property': 'Other Property account for 2.883 percent of Crime in District',
#   'Nuisance, mischief ': 'Nuisance, Mischief  account for 1.175 percent of Crime in District',
#   'Traffic related calls': 'Traffic Related Calls account for 12.122 percent of Crime in District',
#   'Suspicious circumstances': 'Suspicious Circumstances account for 8.872 percent of Crime in District',
#   'Mental health': 'Mental Health account for 1.58 percent of Crime in District',
#   'Liquor violations': 'Liquor Violations account for 21.465 percent of Crime in District',
#   'Trespass': 'Trespass account for 4.304 percent of Crime in District',
#   'Assaults': 'Assaults account for 2.718 percent of Crime in District',
#   'Narcotics complaints': 'Narcotics Complaints account for 4.608 percent of Crime in District',
#   'Accident investigation': 'Accident Investigation account for 1.837 percent of Crime in District',
#   'Shoplifting': 'Shoplifting account for 3.955 percent of Crime in District',
#   'Prowler': 'Prowler account for 0.083 percent of Crime in District',
#   'Burglary': 'Burglary account for 0.641 percent of Crime in District',
#   'Hazards': 'Hazards account for 0.922 percent of Crime in District',
#   'Property damage': 'Property Damage account for 1.064 percent of Crime in District',
#   'Car prowl': 'Car Prowl account for 2.489 percent of Crime in District',
#   'Bike': 'Bike account for 0.204 percent of Crime in District',
#   'Prostitution': 'Prostitution account for 0.117 percent of Crime in District',
#   'Miscellaneous misdemeanors': 'Miscellaneous Misdemeanors account for 0.931 percent of Crime in District',
#   'Animal complaints': 'Animal Complaints account for 0.082 percent of Crime in District',
#   'Threats, harassment': 'Threats, Harassment account for 0.969 percent of Crime in District',
#   'Person down/injury': 'Person Down/Injury account for 0.743 percent of Crime in District',
#   'Auto thefts': 'Auto Thefts account for 0.618 percent of Crime in District',
#   'Persons - lost, found, missing': 'Persons - Lost, Found, Missing account for 0.263 percent of Crime in District',
#   'False alarms': 'False Alarms account for 1.126 percent of Crime in District',
#   'Robbery': 'Robbery account for 0.682 percent of Crime in District',
#   'Arrest': 'Arrest account for 1.909 percent of Crime in District',
#   'False alacad': 'False Alacad account for 0.394 percent of Crime in District',
#   'Property - missing, found': 'Property - Missing, Found account for 0.847 percent of Crime in District',
#   'Reckless burning': 'Reckless Burning account for 0.016 percent of Crime in District',
#   'Behavioral health': 'Behavioral Health account for 1.043 percent of Crime in District',
#   'Weapons calls': 'Weapons Calls account for 0.241 percent of Crime in District',
#   'Nuisance, mischief': 'Nuisance, Mischief account for 3.113 percent of Crime in District',
#   'Lewd conduct': 'Lewd Conduct account for 0.28 percent of Crime in District',
#   'Fraud calls': 'Fraud Calls account for 0.602 percent of Crime in District',
#   'Harbor calls': 'Harbor Calls account for 0.008 percent of Crime in District',
#   'Motor vehicle collision investigation': 'Motor Vehicle Collision Investigation account for 1.618 percent of Crime in District',
#   'Drive by (no injury)': 'Drive By (No Injury) account for 0.006 percent of Crime in District',
#   'Other vice': 'Other Vice account for 0.023 percent of Crime in District',
#   'Failure to register (sex offender)': 'Failure To Register (Sex Offender) account for 0.014 percent of Crime in District',
#   'Homicide': 'Homicide account for 0.017 percent of Crime in District',
#   'Vice calls': 'Vice Calls account for 0.002 percent of Crime in District',
#   'Public gatherings': 'Public Gatherings account for 0.03 percent of Crime in District'},
#  'District N': {'Disturbances': 'Disturbances account for 13.728 percent of Crime in District',
#   'Other property': 'Other Property account for 3.4 percent of Crime in District',
#   'Nuisance, mischief ': 'Nuisance, Mischief  account for 0.388 percent of Crime in District',
#   'Traffic related calls': 'Traffic Related Calls account for 14.838 percent of Crime in District',
#   'Suspicious circumstances': 'Suspicious Circumstances account for 20.074 percent of Crime in District',
#   'Mental health': 'Mental Health account for 1.571 percent of Crime in District',
#   'Liquor violations': 'Liquor Violations account for 0.729 percent of Crime in District',
#   'Trespass': 'Trespass account for 2.546 percent of Crime in District',
#   'Assaults': 'Assaults account for 1.641 percent of Crime in District',
#   'Narcotics complaints': 'Narcotics Complaints account for 1.789 percent of Crime in District',
#   'Accident investigation': 'Accident Investigation account for 3.246 percent of Crime in District',
#   'Shoplifting': 'Shoplifting account for 2.948 percent of Crime in District',
#   'Prowler': 'Prowler account for 0.154 percent of Crime in District',
#   'Burglary': 'Burglary account for 3.214 percent of Crime in District',
#   'Hazards': 'Hazards account for 1.261 percent of Crime in District',
#   'Property damage': 'Property Damage account for 1.663 percent of Crime in District',
#   'Car prowl': 'Car Prowl account for 3.384 percent of Crime in District',
#   'Bike': 'Bike account for 0.276 percent of Crime in District',
#   'Prostitution': 'Prostitution account for 2.185 percent of Crime in District',
#   'Miscellaneous misdemeanors': 'Miscellaneous Misdemeanors account for 0.239 percent of Crime in District',
#   'Animal complaints': 'Animal Complaints account for 0.256 percent of Crime in District',
#   'Threats, harassment': 'Threats, Harassment account for 1.349 percent of Crime in District',
#   'Person down/injury': 'Person Down/Injury account for 0.717 percent of Crime in District',
#   'Auto thefts': 'Auto Thefts account for 2.899 percent of Crime in District',
#   'Persons - lost, found, missing': 'Persons - Lost, Found, Missing account for 0.601 percent of Crime in District',
#   'False alarms': 'False Alarms account for 2.191 percent of Crime in District',
#   'Robbery': 'Robbery account for 0.611 percent of Crime in District',
#   'Arrest': 'Arrest account for 1.561 percent of Crime in District',
#   'False alacad': 'False Alacad account for 1.295 percent of Crime in District',
#   'Property - missing, found': 'Property - Missing, Found account for 1.677 percent of Crime in District',
#   'Reckless burning': 'Reckless Burning account for 0.02 percent of Crime in District',
#   'Behavioral health': 'Behavioral Health account for 0.896 percent of Crime in District',
#   'Weapons calls': 'Weapons Calls account for 0.251 percent of Crime in District',
#   'Nuisance, mischief': 'Nuisance, Mischief account for 1.722 percent of Crime in District',
#   'Lewd conduct': 'Lewd Conduct account for 0.225 percent of Crime in District',
#   'Fraud calls': 'Fraud Calls account for 1.72 percent of Crime in District',
#   'Harbor calls': 'Harbor Calls account for 0.007 percent of Crime in District',
#   'Motor vehicle collision investigation': 'Motor Vehicle Collision Investigation account for 2.524 percent of Crime in District',
#   'Drive by (no injury)': 'Drive By (No Injury) account for 0.005 percent of Crime in District',
#   'Other vice': 'Other Vice account for 0.165 percent of Crime in District',
#   'Failure to register (sex offender)': 'Failure To Register (Sex Offender) account for 0.008 percent of Crime in District',
#   'Homicide': 'Homicide account for 0.017 percent of Crime in District',
#   'Vice calls': 'Vice Calls account for 0.001 percent of Crime in District',
#   'Public gatherings': 'Public Gatherings account for 0.006 percent of Crime in District'},
#  'District S': {'Disturbances': 'Disturbances account for 13.249 percent of Crime in District',
#   'Other property': 'Other Property account for 2.506 percent of Crime in District',
#   'Nuisance, mischief ': 'Nuisance, Mischief  account for 0.383 percent of Crime in District',
#   'Traffic related calls': 'Traffic Related Calls account for 20.327 percent of Crime in District',
#   'Suspicious circumstances': 'Suspicious Circumstances account for 18.863 percent of Crime in District',
#   'Mental health': 'Mental Health account for 1.258 percent of Crime in District',
#   'Liquor violations': 'Liquor Violations account for 0.949 percent of Crime in District',
#   'Trespass': 'Trespass account for 1.658 percent of Crime in District',
#   'Assaults': 'Assaults account for 1.602 percent of Crime in District',
#   'Narcotics complaints': 'Narcotics Complaints account for 1.283 percent of Crime in District',
#   'Accident investigation': 'Accident Investigation account for 2.888 percent of Crime in District',
#   'Shoplifting': 'Shoplifting account for 1.848 percent of Crime in District',
#   'Prowler': 'Prowler account for 0.15 percent of Crime in District',
#   'Burglary': 'Burglary account for 3.652 percent of Crime in District',
#   'Hazards': 'Hazards account for 0.953 percent of Crime in District',
#   'Property damage': 'Property Damage account for 1.972 percent of Crime in District',
#   'Car prowl': 'Car Prowl account for 2.487 percent of Crime in District',
#   'Bike': 'Bike account for 0.095 percent of Crime in District',
#   'Prostitution': 'Prostitution account for 0.141 percent of Crime in District',
#   'Miscellaneous misdemeanors': 'Miscellaneous Misdemeanors account for 0.12 percent of Crime in District',
#   'Animal complaints': 'Animal Complaints account for 0.533 percent of Crime in District',
#   'Threats, harassment': 'Threats, Harassment account for 1.344 percent of Crime in District',
#   'Person down/injury': 'Person Down/Injury account for 0.52 percent of Crime in District',
#   'Auto thefts': 'Auto Thefts account for 3.768 percent of Crime in District',
#   'Persons - lost, found, missing': 'Persons - Lost, Found, Missing account for 0.894 percent of Crime in District',
#   'False alarms': 'False Alarms account for 3.335 percent of Crime in District',
#   'Robbery': 'Robbery account for 1.204 percent of Crime in District',
#   'Arrest': 'Arrest account for 1.324 percent of Crime in District',
#   'False alacad': 'False Alacad account for 2.221 percent of Crime in District',
#   'Property - missing, found': 'Property - Missing, Found account for 0.932 percent of Crime in District',
#   'Reckless burning': 'Reckless Burning account for 0.016 percent of Crime in District',
#   'Behavioral health': 'Behavioral Health account for 0.595 percent of Crime in District',
#   'Weapons calls': 'Weapons Calls account for 0.472 percent of Crime in District',
#   'Nuisance, mischief': 'Nuisance, Mischief account for 0.952 percent of Crime in District',
#   'Lewd conduct': 'Lewd Conduct account for 0.153 percent of Crime in District',
#   'Fraud calls': 'Fraud Calls account for 1.299 percent of Crime in District',
#   'Harbor calls': 'Harbor Calls account for 0.048 percent of Crime in District',
#   'Motor vehicle collision investigation': 'Motor Vehicle Collision Investigation account for 3.376 percent of Crime in District',
#   'Drive by (no injury)': 'Drive By (No Injury) account for 0.371 percent of Crime in District',
#   'Other vice': 'Other Vice account for 0.048 percent of Crime in District',
#   'Failure to register (sex offender)': 'Failure To Register (Sex Offender) account for 0.151 percent of Crime in District',
#   'Homicide': 'Homicide account for 0.048 percent of Crime in District',
#   'Vice calls': 'Vice Calls account for 0.003 percent of Crime in District',
#   'Public gatherings': 'Public Gatherings account for 0.01 percent of Crime in District'},
#  'District F': {'Disturbances': 'Disturbances account for 15.936 percent of Crime in District',
#   'Other property': 'Other Property account for 3.078 percent of Crime in District',
#   'Nuisance, mischief ': 'Nuisance, Mischief  account for 0.777 percent of Crime in District',
#   'Traffic related calls': 'Traffic Related Calls account for 15.014 percent of Crime in District',
#   'Suspicious circumstances': 'Suspicious Circumstances account for 20.41 percent of Crime in District',
#   'Mental health': 'Mental Health account for 1.443 percent of Crime in District',
#   'Liquor violations': 'Liquor Violations account for 0.555 percent of Crime in District',
#   'Trespass': 'Trespass account for 1.239 percent of Crime in District',
#   'Assaults': 'Assaults account for 1.813 percent of Crime in District',
#   'Narcotics complaints': 'Narcotics Complaints account for 1.114 percent of Crime in District',
#   'Accident investigation': 'Accident Investigation account for 3.031 percent of Crime in District',
#   'Shoplifting': 'Shoplifting account for 2.736 percent of Crime in District',
#   'Prowler': 'Prowler account for 0.114 percent of Crime in District',
#   'Burglary': 'Burglary account for 3.57 percent of Crime in District',
#   'Hazards': 'Hazards account for 1.487 percent of Crime in District',
#   'Property damage': 'Property Damage account for 2.319 percent of Crime in District',
#   'Car prowl': 'Car Prowl account for 3.01 percent of Crime in District',
#   'Bike': 'Bike account for 0.184 percent of Crime in District',
#   'Prostitution': 'Prostitution account for 0.068 percent of Crime in District',
#   'Miscellaneous misdemeanors': 'Miscellaneous Misdemeanors account for 0.129 percent of Crime in District',
#   'Animal complaints': 'Animal Complaints account for 0.513 percent of Crime in District',
#   'Threats, harassment': 'Threats, Harassment account for 1.482 percent of Crime in District',
#   'Person down/injury': 'Person Down/Injury account for 0.604 percent of Crime in District',
#   'Auto thefts': 'Auto Thefts account for 3.811 percent of Crime in District',
#   'Persons - lost, found, missing': 'Persons - Lost, Found, Missing account for 0.754 percent of Crime in District',
#   'False alarms': 'False Alarms account for 2.949 percent of Crime in District',
#   'Robbery': 'Robbery account for 0.645 percent of Crime in District',
#   'Arrest': 'Arrest account for 1.003 percent of Crime in District',
#   'False alacad': 'False Alacad account for 1.702 percent of Crime in District',
#   'Property - missing, found': 'Property - Missing, Found account for 1.27 percent of Crime in District',
#   'Reckless burning': 'Reckless Burning account for 0.036 percent of Crime in District',
#   'Behavioral health': 'Behavioral Health account for 0.669 percent of Crime in District',
#   'Weapons calls': 'Weapons Calls account for 0.337 percent of Crime in District',
#   'Nuisance, mischief': 'Nuisance, Mischief account for 1.741 percent of Crime in District',
#   'Lewd conduct': 'Lewd Conduct account for 0.179 percent of Crime in District',
#   'Fraud calls': 'Fraud Calls account for 1.347 percent of Crime in District',
#   'Harbor calls': 'Harbor Calls account for 0.01 percent of Crime in District',
#   'Motor vehicle collision investigation': 'Motor Vehicle Collision Investigation account for 2.819 percent of Crime in District',
#   'Drive by (no injury)': 'Drive By (No Injury) account for 0.041 percent of Crime in District',
#   'Other vice': 'Other Vice account for 0.016 percent of Crime in District',
#   'Failure to register (sex offender)': 'Failure To Register (Sex Offender) account for 0.013 percent of Crime in District',
#   'Homicide': 'Homicide account for 0.023 percent of Crime in District',
#   'Vice calls': 'Vice Calls account for 0.0 percent of Crime in District',
#   'Public gatherings': 'Public Gatherings account for 0.008 percent of Crime in District'},
#  'District J': {'Disturbances': 'Disturbances account for 12.523 percent of Crime in District',
#   'Other property': 'Other Property account for 2.523 percent of Crime in District',
#   'Nuisance, mischief ': 'Nuisance, Mischief  account for 0.682 percent of Crime in District',
#   'Traffic related calls': 'Traffic Related Calls account for 22.629 percent of Crime in District',
#   'Suspicious circumstances': 'Suspicious Circumstances account for 17.553 percent of Crime in District',
#   'Mental health': 'Mental Health account for 1.309 percent of Crime in District',
#   'Liquor violations': 'Liquor Violations account for 1.268 percent of Crime in District',
#   'Trespass': 'Trespass account for 1.96 percent of Crime in District',
#   'Assaults': 'Assaults account for 1.231 percent of Crime in District',
#   'Narcotics complaints': 'Narcotics Complaints account for 0.902 percent of Crime in District',
#   'Accident investigation': 'Accident Investigation account for 3.697 percent of Crime in District',
#   'Shoplifting': 'Shoplifting account for 1.44 percent of Crime in District',
#   'Prowler': 'Prowler account for 0.236 percent of Crime in District',
#   'Burglary': 'Burglary account for 3.762 percent of Crime in District',
#   'Hazards': 'Hazards account for 1.425 percent of Crime in District',
#   'Property damage': 'Property Damage account for 1.891 percent of Crime in District',
#   'Car prowl': 'Car Prowl account for 4.673 percent of Crime in District',
#   'Bike': 'Bike account for 0.495 percent of Crime in District',
#   'Prostitution': 'Prostitution account for 0.17 percent of Crime in District',
#   'Miscellaneous misdemeanors': 'Miscellaneous Misdemeanors account for 0.175 percent of Crime in District',
#   'Animal complaints': 'Animal Complaints account for 0.349 percent of Crime in District',
#   'Threats, harassment': 'Threats, Harassment account for 1.016 percent of Crime in District',
#   'Person down/injury': 'Person Down/Injury account for 0.577 percent of Crime in District',
#   'Auto thefts': 'Auto Thefts account for 3.103 percent of Crime in District',
#   'Persons - lost, found, missing': 'Persons - Lost, Found, Missing account for 0.384 percent of Crime in District',
#   'False alarms': 'False Alarms account for 3.33 percent of Crime in District',
#   'Robbery': 'Robbery account for 0.295 percent of Crime in District',
#   'Arrest': 'Arrest account for 0.678 percent of Crime in District',
#   'False alacad': 'False Alacad account for 1.719 percent of Crime in District',
#   'Property - missing, found': 'Property - Missing, Found account for 1.158 percent of Crime in District',
#   'Reckless burning': 'Reckless Burning account for 0.016 percent of Crime in District',
#   'Behavioral health': 'Behavioral Health account for 0.682 percent of Crime in District',
#   'Weapons calls': 'Weapons Calls account for 0.15 percent of Crime in District',
#   'Nuisance, mischief': 'Nuisance, Mischief account for 1.525 percent of Crime in District',
#   'Lewd conduct': 'Lewd Conduct account for 0.326 percent of Crime in District',
#   'Fraud calls': 'Fraud Calls account for 1.49 percent of Crime in District',
#   'Harbor calls': 'Harbor Calls account for 0.115 percent of Crime in District',
#   'Motor vehicle collision investigation': 'Motor Vehicle Collision Investigation account for 2.501 percent of Crime in District',
#   'Drive by (no injury)': 'Drive By (No Injury) account for 0.01 percent of Crime in District',
#   'Other vice': 'Other Vice account for 0.013 percent of Crime in District',
#   'Failure to register (sex offender)': 'Failure To Register (Sex Offender) account for 0.007 percent of Crime in District',
#   'Homicide': 'Homicide account for 0.007 percent of Crime in District',
#   'Vice calls': 'Vice Calls account for 0.001 percent of Crime in District',
#   'Public gatherings': 'Public Gatherings account for 0.004 percent of Crime in District'},
#  'District L': {'Disturbances': 'Disturbances account for 14.93 percent of Crime in District',
#   'Other property': 'Other Property account for 3.084 percent of Crime in District',
#   'Nuisance, mischief ': 'Nuisance, Mischief  account for 0.578 percent of Crime in District',
#   'Traffic related calls': 'Traffic Related Calls account for 14.315 percent of Crime in District',
#   'Suspicious circumstances': 'Suspicious Circumstances account for 19.72 percent of Crime in District',
#   'Mental health': 'Mental Health account for 1.524 percent of Crime in District',
#   'Liquor violations': 'Liquor Violations account for 1.003 percent of Crime in District',
#   'Trespass': 'Trespass account for 2.106 percent of Crime in District',
#   'Assaults': 'Assaults account for 1.431 percent of Crime in District',
#   'Narcotics complaints': 'Narcotics Complaints account for 0.849 percent of Crime in District',
#   'Accident investigation': 'Accident Investigation account for 2.771 percent of Crime in District',
#   'Shoplifting': 'Shoplifting account for 4.05 percent of Crime in District',
#   'Prowler': 'Prowler account for 0.23 percent of Crime in District',
#   'Burglary': 'Burglary account for 4.288 percent of Crime in District',
#   'Hazards': 'Hazards account for 1.266 percent of Crime in District',
#   'Property damage': 'Property Damage account for 1.745 percent of Crime in District',
#   'Car prowl': 'Car Prowl account for 3.171 percent of Crime in District',
#   'Bike': 'Bike account for 0.235 percent of Crime in District',
#   'Prostitution': 'Prostitution account for 0.028 percent of Crime in District',
#   'Miscellaneous misdemeanors': 'Miscellaneous Misdemeanors account for 0.148 percent of Crime in District',
#   'Animal complaints': 'Animal Complaints account for 0.372 percent of Crime in District',
#   'Threats, harassment': 'Threats, Harassment account for 1.369 percent of Crime in District',
#   'Person down/injury': 'Person Down/Injury account for 0.73 percent of Crime in District',
#   'Auto thefts': 'Auto Thefts account for 2.671 percent of Crime in District',
#   'Persons - lost, found, missing': 'Persons - Lost, Found, Missing account for 0.78 percent of Crime in District',
#   'False alarms': 'False Alarms account for 4.436 percent of Crime in District',
#   'Robbery': 'Robbery account for 0.58 percent of Crime in District',
#   'Arrest': 'Arrest account for 1.096 percent of Crime in District',
#   'False alacad': 'False Alacad account for 1.762 percent of Crime in District',
#   'Property - missing, found': 'Property - Missing, Found account for 1.083 percent of Crime in District',
#   'Reckless burning': 'Reckless Burning account for 0.013 percent of Crime in District',
#   'Behavioral health': 'Behavioral Health account for 0.923 percent of Crime in District',
#   'Weapons calls': 'Weapons Calls account for 0.156 percent of Crime in District',
#   'Nuisance, mischief': 'Nuisance, Mischief account for 1.261 percent of Crime in District',
#   'Lewd conduct': 'Lewd Conduct account for 0.172 percent of Crime in District',
#   'Fraud calls': 'Fraud Calls account for 1.888 percent of Crime in District',
#   'Harbor calls': 'Harbor Calls account for 0.104 percent of Crime in District',
#   'Motor vehicle collision investigation': 'Motor Vehicle Collision Investigation account for 3.069 percent of Crime in District',
#   'Drive by (no injury)': 'Drive By (No Injury) account for 0.011 percent of Crime in District',
#   'Other vice': 'Other Vice account for 0.013 percent of Crime in District',
#   'Failure to register (sex offender)': 'Failure To Register (Sex Offender) account for 0.013 percent of Crime in District',
#   'Homicide': 'Homicide account for 0.007 percent of Crime in District',
#   'Vice calls': 'Vice Calls account for 0.001 percent of Crime in District',
#   'Public gatherings': 'Public Gatherings account for 0.017 percent of Crime in District'},
#  'District W': {'Disturbances': 'Disturbances account for 13.085 percent of Crime in District',
#   'Other property': 'Other Property account for 2.53 percent of Crime in District',
#   'Nuisance, mischief ': 'Nuisance, Mischief  account for 0.68 percent of Crime in District',
#   'Traffic related calls': 'Traffic Related Calls account for 21.519 percent of Crime in District',
#   'Suspicious circumstances': 'Suspicious Circumstances account for 17.574 percent of Crime in District',
#   'Mental health': 'Mental Health account for 1.285 percent of Crime in District',
#   'Liquor violations': 'Liquor Violations account for 0.84 percent of Crime in District',
#   'Trespass': 'Trespass account for 0.967 percent of Crime in District',
#   'Assaults': 'Assaults account for 1.003 percent of Crime in District',
#   'Narcotics complaints': 'Narcotics Complaints account for 0.651 percent of Crime in District',
#   'Accident investigation': 'Accident Investigation account for 2.826 percent of Crime in District',
#   'Shoplifting': 'Shoplifting account for 1.41 percent of Crime in District',
#   'Prowler': 'Prowler account for 0.137 percent of Crime in District',
#   'Burglary': 'Burglary account for 3.459 percent of Crime in District',
#   'Hazards': 'Hazards account for 1.816 percent of Crime in District',
#   'Property damage': 'Property Damage account for 2.005 percent of Crime in District',
#   'Car prowl': 'Car Prowl account for 3.442 percent of Crime in District',
#   'Bike': 'Bike account for 0.198 percent of Crime in District',
#   'Prostitution': 'Prostitution account for 0.023 percent of Crime in District',
#   'Miscellaneous misdemeanors': 'Miscellaneous Misdemeanors account for 2.97 percent of Crime in District',
#   'Animal complaints': 'Animal Complaints account for 0.54 percent of Crime in District',
#   'Threats, harassment': 'Threats, Harassment account for 1.115 percent of Crime in District',
#   'Person down/injury': 'Person Down/Injury account for 0.713 percent of Crime in District',
#   'Auto thefts': 'Auto Thefts account for 2.61 percent of Crime in District',
#   'Persons - lost, found, missing': 'Persons - Lost, Found, Missing account for 0.633 percent of Crime in District',
#   'False alarms': 'False Alarms account for 4.564 percent of Crime in District',
#   'Robbery': 'Robbery account for 0.34 percent of Crime in District',
#   'Arrest': 'Arrest account for 0.538 percent of Crime in District',
#   'False alacad': 'False Alacad account for 2.324 percent of Crime in District',
#   'Property - missing, found': 'Property - Missing, Found account for 1.123 percent of Crime in District',
#   'Reckless burning': 'Reckless Burning account for 0.057 percent of Crime in District',
#   'Behavioral health': 'Behavioral Health account for 0.585 percent of Crime in District',
#   'Weapons calls': 'Weapons Calls account for 0.142 percent of Crime in District',
#   'Nuisance, mischief': 'Nuisance, Mischief account for 1.476 percent of Crime in District',
#   'Lewd conduct': 'Lewd Conduct account for 0.176 percent of Crime in District',
#   'Fraud calls': 'Fraud Calls account for 1.49 percent of Crime in District',
#   'Harbor calls': 'Harbor Calls account for 0.117 percent of Crime in District',
#   'Motor vehicle collision investigation': 'Motor Vehicle Collision Investigation account for 2.981 percent of Crime in District',
#   'Drive by (no injury)': 'Drive By (No Injury) account for 0.017 percent of Crime in District',
#   'Other vice': 'Other Vice account for 0.015 percent of Crime in District',
#   'Failure to register (sex offender)': 'Failure To Register (Sex Offender) account for 0.004 percent of Crime in District',
#   'Homicide': 'Homicide account for 0.007 percent of Crime in District',
#   'Vice calls': 'Vice Calls account for 0.0 percent of Crime in District',
#   'Public gatherings': 'Public Gatherings account for 0.012 percent of Crime in District'},
#  'District E': {'Disturbances': 'Disturbances account for 16.62 percent of Crime in District',
#   'Other property': 'Other Property account for 2.819 percent of Crime in District',
#   'Nuisance, mischief ': 'Nuisance, Mischief  account for 0.293 percent of Crime in District',
#   'Traffic related calls': 'Traffic Related Calls account for 18.071 percent of Crime in District',
#   'Suspicious circumstances': 'Suspicious Circumstances account for 13.803 percent of Crime in District',
#   'Mental health': 'Mental Health account for 1.44 percent of Crime in District',
#   'Liquor violations': 'Liquor Violations account for 8.374 percent of Crime in District',
#   'Trespass': 'Trespass account for 5.999 percent of Crime in District',
#   'Assaults': 'Assaults account for 2.457 percent of Crime in District',
#   'Narcotics complaints': 'Narcotics Complaints account for 1.838 percent of Crime in District',
#   'Accident investigation': 'Accident Investigation account for 1.928 percent of Crime in District',
#   'Shoplifting': 'Shoplifting account for 1.746 percent of Crime in District',
#   'Prowler': 'Prowler account for 0.105 percent of Crime in District',
#   'Burglary': 'Burglary account for 2.078 percent of Crime in District',
#   'Hazards': 'Hazards account for 0.678 percent of Crime in District',
#   'Property damage': 'Property Damage account for 1.633 percent of Crime in District',
#   'Car prowl': 'Car Prowl account for 2.831 percent of Crime in District',
#   'Bike': 'Bike account for 0.372 percent of Crime in District',
#   'Prostitution': 'Prostitution account for 0.065 percent of Crime in District',
# ...
#   'Motor vehicle collision investigation': 'Motor Vehicle Collision Investigation account for 3.066 percent of Crime in District',
#   'Drive by (no injury)': 'Drive By (No Injury) account for 0.079 percent of Crime in District',
#   'Other vice': 'Other Vice account for 0.027 percent of Crime in District',
#   'Failure to register (sex offender)': 'Failure To Register (Sex Offender) account for 0.04 percent of Crime in District',
#   'Homicide': 'Homicide account for 0.025 percent of Crime in District',
#   'Vice calls': 'Vice Calls account for 0.0 percent of Crime in District',
#   'Public gatherings': 'Public Gatherings account for 0.036 percent of Crime in District'},
#  'District B': {'Disturbances': 'Disturbances account for 13.883 percent of Crime in District',
#   'Other property': 'Other Property account for 2.468 percent of Crime in District',
#   'Nuisance, mischief ': 'Nuisance, Mischief  account for 0.442 percent of Crime in District',
#   'Traffic related calls': 'Traffic Related Calls account for 19.736 percent of Crime in District',
#   'Suspicious circumstances': 'Suspicious Circumstances account for 18.252 percent of Crime in District',
#   'Mental health': 'Mental Health account for 1.162 percent of Crime in District',
#   'Liquor violations': 'Liquor Violations account for 1.154 percent of Crime in District',
#   'Trespass': 'Trespass account for 2.257 percent of Crime in District',
#   'Assaults': 'Assaults account for 1.285 percent of Crime in District',
#   'Narcotics complaints': 'Narcotics Complaints account for 0.804 percent of Crime in District',
#   'Accident investigation': 'Accident Investigation account for 2.594 percent of Crime in District',
#   'Shoplifting': 'Shoplifting account for 2.098 percent of Crime in District',
#   'Prowler': 'Prowler account for 0.179 percent of Crime in District',
#   'Burglary': 'Burglary account for 3.932 percent of Crime in District',
#   'Hazards': 'Hazards account for 1.588 percent of Crime in District',
#   'Property damage': 'Property Damage account for 2.014 percent of Crime in District',
#   'Car prowl': 'Car Prowl account for 3.724 percent of Crime in District',
#   'Bike': 'Bike account for 0.538 percent of Crime in District',
#   'Prostitution': 'Prostitution account for 0.02 percent of Crime in District',
#   'Miscellaneous misdemeanors': 'Miscellaneous Misdemeanors account for 0.155 percent of Crime in District',
#   'Animal complaints': 'Animal Complaints account for 0.32 percent of Crime in District',
#   'Threats, harassment': 'Threats, Harassment account for 1.066 percent of Crime in District',
#   'Person down/injury': 'Person Down/Injury account for 0.689 percent of Crime in District',
#   'Auto thefts': 'Auto Thefts account for 2.812 percent of Crime in District',
#   'Persons - lost, found, missing': 'Persons - Lost, Found, Missing account for 0.512 percent of Crime in District',
#   'False alarms': 'False Alarms account for 3.079 percent of Crime in District',
#   'Robbery': 'Robbery account for 0.391 percent of Crime in District',
#   'Arrest': 'Arrest account for 0.654 percent of Crime in District',
#   'False alacad': 'False Alacad account for 1.968 percent of Crime in District',
#   'Property - missing, found': 'Property - Missing, Found account for 1.036 percent of Crime in District',
#   'Reckless burning': 'Reckless Burning account for 0.018 percent of Crime in District',
#   'Behavioral health': 'Behavioral Health account for 0.915 percent of Crime in District',
#   'Weapons calls': 'Weapons Calls account for 0.149 percent of Crime in District',
#   'Nuisance, mischief': 'Nuisance, Mischief account for 2.667 percent of Crime in District',
#   'Lewd conduct': 'Lewd Conduct account for 0.221 percent of Crime in District',
#   'Fraud calls': 'Fraud Calls account for 1.419 percent of Crime in District',
#   'Harbor calls': 'Harbor Calls account for 0.264 percent of Crime in District',
#   'Motor vehicle collision investigation': 'Motor Vehicle Collision Investigation account for 3.476 percent of Crime in District',
#   'Drive by (no injury)': 'Drive By (No Injury) account for 0.018 percent of Crime in District',
#   'Other vice': 'Other Vice account for 0.013 percent of Crime in District',
#   'Failure to register (sex offender)': 'Failure To Register (Sex Offender) account for 0.004 percent of Crime in District',
#   'Homicide': 'Homicide account for 0.007 percent of Crime in District',
#   'Vice calls': 'Vice Calls account for 0.002 percent of Crime in District',
#   'Public gatherings': 'Public Gatherings account for 0.014 percent of Crime in District'},
#  'District O': {'Disturbances': 'Disturbances account for 9.413 percent of Crime in District',
#   'Other property': 'Other Property account for 2.529 percent of Crime in District',
#   'Nuisance, mischief ': 'Nuisance, Mischief  account for 0.998 percent of Crime in District',
#   'Traffic related calls': 'Traffic Related Calls account for 24.335 percent of Crime in District',
#   'Suspicious circumstances': 'Suspicious Circumstances account for 13.996 percent of Crime in District',
#   'Mental health': 'Mental Health account for 0.823 percent of Crime in District',
#   'Liquor violations': 'Liquor Violations account for 8.027 percent of Crime in District',
#   'Trespass': 'Trespass account for 1.99 percent of Crime in District',
#   'Assaults': 'Assaults account for 1.519 percent of Crime in District',
#   'Narcotics complaints': 'Narcotics Complaints account for 1.306 percent of Crime in District',
#   'Accident investigation': 'Accident Investigation account for 4.188 percent of Crime in District',
#   'Shoplifting': 'Shoplifting account for 1.165 percent of Crime in District',
#   'Prowler': 'Prowler account for 0.098 percent of Crime in District',
#   'Burglary': 'Burglary account for 2.788 percent of Crime in District',
#   'Hazards': 'Hazards account for 2.274 percent of Crime in District',
#   'Property damage': 'Property Damage account for 1.752 percent of Crime in District',
#   'Car prowl': 'Car Prowl account for 2.91 percent of Crime in District',
#   'Bike': 'Bike account for 0.149 percent of Crime in District',
#   'Prostitution': 'Prostitution account for 0.23 percent of Crime in District',
#   'Miscellaneous misdemeanors': 'Miscellaneous Misdemeanors account for 0.152 percent of Crime in District',
#   'Animal complaints': 'Animal Complaints account for 0.215 percent of Crime in District',
#   'Threats, harassment': 'Threats, Harassment account for 0.917 percent of Crime in District',
#   'Person down/injury': 'Person Down/Injury account for 0.44 percent of Crime in District',
#   'Auto thefts': 'Auto Thefts account for 2.586 percent of Crime in District',
#   'Persons - lost, found, missing': 'Persons - Lost, Found, Missing account for 0.295 percent of Crime in District',
#   'False alarms': 'False Alarms account for 3.736 percent of Crime in District',
#   'Robbery': 'Robbery account for 0.548 percent of Crime in District',
#   'Arrest': 'Arrest account for 1.152 percent of Crime in District',
#   'False alacad': 'False Alacad account for 1.953 percent of Crime in District',
#   'Property - missing, found': 'Property - Missing, Found account for 0.812 percent of Crime in District',
#   'Reckless burning': 'Reckless Burning account for 0.025 percent of Crime in District',
#   'Behavioral health': 'Behavioral Health account for 0.53 percent of Crime in District',
#   'Weapons calls': 'Weapons Calls account for 0.296 percent of Crime in District',
#   'Nuisance, mischief': 'Nuisance, Mischief account for 1.065 percent of Crime in District',
#   'Lewd conduct': 'Lewd Conduct account for 0.177 percent of Crime in District',
#   'Fraud calls': 'Fraud Calls account for 0.843 percent of Crime in District',
#   'Harbor calls': 'Harbor Calls account for 0.013 percent of Crime in District',
#   'Motor vehicle collision investigation': 'Motor Vehicle Collision Investigation account for 3.53 percent of Crime in District',
#   'Drive by (no injury)': 'Drive By (No Injury) account for 0.053 percent of Crime in District',
#   'Other vice': 'Other Vice account for 0.021 percent of Crime in District',
#   'Failure to register (sex offender)': 'Failure To Register (Sex Offender) account for 0.103 percent of Crime in District',
#   'Homicide': 'Homicide account for 0.038 percent of Crime in District',
#   'Vice calls': 'Vice Calls account for 0.003 percent of Crime in District',
#   'Public gatherings': 'Public Gatherings account for 0.006 percent of Crime in District'},
#  'District 99': {'Disturbances': 'Disturbances account for 5.66 percent of Crime in District',
#   'Other property': 'Other Property account for 0.943 percent of Crime in District',
#   'Nuisance, mischief ': 'Nuisance, Mischief  account for 0.0 percent of Crime in District',
#   'Traffic related calls': 'Traffic Related Calls account for 51.887 percent of Crime in District',
#   'Suspicious circumstances': 'Suspicious Circumstances account for 9.434 percent of Crime in District',
#   'Mental health': 'Mental Health account for 0.0 percent of Crime in District',
#   'Liquor violations': 'Liquor Violations account for 0.0 percent of Crime in District',
#   'Trespass': 'Trespass account for 0.0 percent of Crime in District',
#   'Assaults': 'Assaults account for 1.887 percent of Crime in District',
#   'Narcotics complaints': 'Narcotics Complaints account for 0.943 percent of Crime in District',
#   'Accident investigation': 'Accident Investigation account for 0.943 percent of Crime in District',
#   'Shoplifting': 'Shoplifting account for 1.887 percent of Crime in District',
#   'Prowler': 'Prowler account for 0.0 percent of Crime in District',
#   'Burglary': 'Burglary account for 0.0 percent of Crime in District',
#   'Hazards': 'Hazards account for 1.887 percent of Crime in District',
#   'Property damage': 'Property Damage account for 1.887 percent of Crime in District',
#   'Car prowl': 'Car Prowl account for 0.0 percent of Crime in District',
#   'Bike': 'Bike account for 0.0 percent of Crime in District',
#   'Prostitution': 'Prostitution account for 0.0 percent of Crime in District',
#   'Miscellaneous misdemeanors': 'Miscellaneous Misdemeanors account for 0.0 percent of Crime in District',
#   'Animal complaints': 'Animal Complaints account for 0.943 percent of Crime in District',
#   'Threats, harassment': 'Threats, Harassment account for 0.0 percent of Crime in District',
#   'Person down/injury': 'Person Down/Injury account for 2.83 percent of Crime in District',
#   'Auto thefts': 'Auto Thefts account for 2.83 percent of Crime in District',
#   'Persons - lost, found, missing': 'Persons - Lost, Found, Missing account for 0.943 percent of Crime in District',
#   'False alarms': 'False Alarms account for 0.0 percent of Crime in District',
#   'Robbery': 'Robbery account for 1.887 percent of Crime in District',
#   'Arrest': 'Arrest account for 5.66 percent of Crime in District',
#   'False alacad': 'False Alacad account for 0.0 percent of Crime in District',
#   'Property - missing, found': 'Property - Missing, Found account for 0.943 percent of Crime in District',
#   'Reckless burning': 'Reckless Burning account for 0.0 percent of Crime in District',
#   'Behavioral health': 'Behavioral Health account for 1.887 percent of Crime in District',
#   'Weapons calls': 'Weapons Calls account for 1.887 percent of Crime in District',
#   'Nuisance, mischief': 'Nuisance, Mischief account for 0.943 percent of Crime in District',
#   'Lewd conduct': 'Lewd Conduct account for 0.0 percent of Crime in District',
#   'Fraud calls': 'Fraud Calls account for 0.0 percent of Crime in District',
#   'Harbor calls': 'Harbor Calls account for 0.0 percent of Crime in District',
#   'Motor vehicle collision investigation': 'Motor Vehicle Collision Investigation account for 1.887 percent of Crime in District',
#   'Drive by (no injury)': 'Drive By (No Injury) account for 0.0 percent of Crime in District',
#   'Other vice': 'Other Vice account for 0.0 percent of Crime in District',
#   'Failure to register (sex offender)': 'Failure To Register (Sex Offender) account for 0.0 percent of Crime in District',
#   'Homicide': 'Homicide account for 0.0 percent of Crime in District',
#   'Vice calls': 'Vice Calls account for 0.0 percent of Crime in District',
#   'Public gatherings': 'Public Gatherings account for 0.0 percent of Crime in District'},
#  'District H': {'Disturbances': 'Disturbances account for 0.0 percent of Crime in District',
#   'Other property': 'Other Property account for 0.0 percent of Crime in District',
#   'Nuisance, mischief ': 'Nuisance, Mischief  account for 0.0 percent of Crime in District',
#   'Traffic related calls': 'Traffic Related Calls account for 22.222 percent of Crime in District',
#   'Suspicious circumstances': 'Suspicious Circumstances account for 0.0 percent of Crime in District',
#   'Mental health': 'Mental Health account for 0.0 percent of Crime in District',
#   'Liquor violations': 'Liquor Violations account for 0.0 percent of Crime in District',
#   'Trespass': 'Trespass account for 0.0 percent of Crime in District',
#   'Assaults': 'Assaults account for 0.0 percent of Crime in District',
#   'Narcotics complaints': 'Narcotics Complaints account for 0.0 percent of Crime in District',
#   'Accident investigation': 'Accident Investigation account for 0.0 percent of Crime in District',
#   'Shoplifting': 'Shoplifting account for 0.0 percent of Crime in District',
#   'Prowler': 'Prowler account for 0.0 percent of Crime in District',
#   'Burglary': 'Burglary account for 0.0 percent of Crime in District',
#   'Hazards': 'Hazards account for 0.0 percent of Crime in District',
#   'Property damage': 'Property Damage account for 11.111 percent of Crime in District',
#   'Car prowl': 'Car Prowl account for 0.0 percent of Crime in District',
#   'Bike': 'Bike account for 0.0 percent of Crime in District',
#   'Prostitution': 'Prostitution account for 0.0 percent of Crime in District',
#   'Miscellaneous misdemeanors': 'Miscellaneous Misdemeanors account for 0.0 percent of Crime in District',
#   'Animal complaints': 'Animal Complaints account for 0.0 percent of Crime in District',
#   'Threats, harassment': 'Threats, Harassment account for 0.0 percent of Crime in District',
#   'Person down/injury': 'Person Down/Injury account for 11.111 percent of Crime in District',
#   'Auto thefts': 'Auto Thefts account for 0.0 percent of Crime in District',
#   'Persons - lost, found, missing': 'Persons - Lost, Found, Missing account for 0.0 percent of Crime in District',
#   'False alarms': 'False Alarms account for 0.0 percent of Crime in District',
#   'Robbery': 'Robbery account for 0.0 percent of Crime in District',
#   'Arrest': 'Arrest account for 0.0 percent of Crime in District',
#   'False alacad': 'False Alacad account for 0.0 percent of Crime in District',
#   'Property - missing, found': 'Property - Missing, Found account for 0.0 percent of Crime in District',
#   'Reckless burning': 'Reckless Burning account for 0.0 percent of Crime in District',
#   'Behavioral health': 'Behavioral Health account for 0.0 percent of Crime in District',
#   'Weapons calls': 'Weapons Calls account for 0.0 percent of Crime in District',
#   'Nuisance, mischief': 'Nuisance, Mischief account for 0.0 percent of Crime in District',
#   'Lewd conduct': 'Lewd Conduct account for 0.0 percent of Crime in District',
#   'Fraud calls': 'Fraud Calls account for 0.0 percent of Crime in District',
#   'Harbor calls': 'Harbor Calls account for 55.556 percent of Crime in District',
#   'Motor vehicle collision investigation': 'Motor Vehicle Collision Investigation account for 0.0 percent of Crime in District',
#   'Drive by (no injury)': 'Drive By (No Injury) account for 0.0 percent of Crime in District',
#   'Other vice': 'Other Vice account for 0.0 percent of Crime in District',
#   'Failure to register (sex offender)': 'Failure To Register (Sex Offender) account for 0.0 percent of Crime in District',
#   'Homicide': 'Homicide account for 0.0 percent of Crime in District',
#   'Vice calls': 'Vice Calls account for 0.0 percent of Crime in District',
#   'Public gatherings': 'Public Gatherings account for 0.0 percent of Crime in District'}}

# %% [markdown]
# ## Slice Data to Smaller Dataset Due to Large Size of Main Dataset

# %%
crimes = crime_df[1000:5000]
crimes.head()
# Out:
#      CAD CDW ID  CAD Event Number  General Offense Number  \
# 1000      16764       10000247611              2010247611
# 1001      16765       10000247756              2010247756
# 1002      16766       10000247785              2010247785
# 1003      16767       10000247789              2010247789
# 1004      16768       10000247788              2010247788
#
#       Event Clearance Code            Event Clearance Description  \
# 1000                  65.0                  THEFT - MISCELLANEOUS
# 1001                 200.0   ALARMS - COMMERCIAL BURGLARY (FALSE)
# 1002                 460.0             TRAFFIC (MOVING) VIOLATION
# 1003                 177.0  LIQUOR VIOLATION - INTOXICATED PERSON
# 1004                 177.0  LIQUOR VIOLATION - INTOXICATED PERSON
#
#      Event Clearance SubGroup  Event Clearance Group Event Clearance Date  \
# 1000                    THEFT         OTHER PROPERTY  2010-07-18 21:41:00
# 1001  BURGLARY ALARMS (FALSE)           FALSE ALARMS  2010-07-18 21:49:00
# 1002    TRAFFIC RELATED CALLS  TRAFFIC RELATED CALLS  2010-07-18 21:56:00
# 1003        LIQUOR VIOLATIONS      LIQUOR VIOLATIONS  2010-07-18 21:59:00
# 1004        LIQUOR VIOLATIONS      LIQUOR VIOLATIONS  2010-07-18 22:09:00
#
#              Hundred Block Location District/Sector Zone/Beat  Census Tract  \
# 1000      88XX BLOCK OF 13TH AVE SW               F        F3    11300.3004
# 1001  81XX BLOCK OF GREENWOOD AVE N               B        B3     2900.1007
# 1002        10XX BLOCK OF S LANE ST               G        G2     9100.1006
# 1003  5XX BLOCK OF QUEEN ANNE AVE N               Q        Q3     7100.2003
# 1004     18XX BLOCK OF NW MARKET ST               J        J2     4700.4002
#
#        Longitude   Latitude               Incident Location
# 1000 -122.351680  47.523774  (47.523774444, -122.351679629)
# 1001 -122.355300  47.688028   (47.68802767, -122.355300312)
# 1002 -122.318055  47.596662  (47.596662187, -122.318054901)
# 1003 -122.356715  47.623930  (47.623929893, -122.356714541)
# 1004 -122.381042  47.668674  (47.668674212, -122.381041843)

# %%
crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 1000 to 5006
# Data columns (total 15 columns):
# CAD CDW ID                     4000 non-null object
# CAD Event Number               4000 non-null int64
# General Offense Number         4000 non-null int64
# Event Clearance Code           4000 non-null float64
# Event Clearance Description    4000 non-null object
# Event Clearance SubGroup       4000 non-null object
# Event Clearance Group          4000 non-null object
# Event Clearance Date           4000 non-null datetime64[ns]
# Hundred Block Location         4000 non-null object
# District/Sector                4000 non-null object
# Zone/Beat                      4000 non-null object
# Census Tract                   4000 non-null float64
# Longitude                      4000 non-null float64
# Latitude                       4000 non-null float64
# Incident Location              4000 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(8)
# memory usage: 500.0+ KB

# %%
crime = crimes[['Event Clearance Group', 'Event Clearance Description', 'Event Clearance Date', 'District/Sector', 
                'Zone/Beat', 'Latitude', 'Longitude', 'Incident Location']]
crime.head()
# Out:
#       Event Clearance Group            Event Clearance Description  \
# 1000         OTHER PROPERTY                  THEFT - MISCELLANEOUS
# 1001           FALSE ALARMS   ALARMS - COMMERCIAL BURGLARY (FALSE)
# 1002  TRAFFIC RELATED CALLS             TRAFFIC (MOVING) VIOLATION
# 1003      LIQUOR VIOLATIONS  LIQUOR VIOLATION - INTOXICATED PERSON
# 1004      LIQUOR VIOLATIONS  LIQUOR VIOLATION - INTOXICATED PERSON
#
#      Event Clearance Date District/Sector Zone/Beat   Latitude   Longitude  \
# 1000  2010-07-18 21:41:00               F        F3  47.523774 -122.351680
# 1001  2010-07-18 21:49:00               B        B3  47.688028 -122.355300
# 1002  2010-07-18 21:56:00               G        G2  47.596662 -122.318055
# 1003  2010-07-18 21:59:00               Q        Q3  47.623930 -122.356715
# 1004  2010-07-18 22:09:00               J        J2  47.668674 -122.381042
#
#                    Incident Location
# 1000  (47.523774444, -122.351679629)
# 1001   (47.68802767, -122.355300312)
# 1002  (47.596662187, -122.318054901)
# 1003  (47.623929893, -122.356714541)
# 1004  (47.668674212, -122.381041843)

# %%
crime['Event Clearance Group'].nunique()
# Out:
# 39

# %% [markdown]
# ## Create List of Locations by Latitude and Longitude from Sliced Data

# %%
locations = crime[['Latitude', 'Longitude']]
locationlist = locations.values.tolist()
print(len(locationlist))
locationlist[:5]
# Out:
# 4000
# [[47.523774444, -122.351679629],
#  [47.68802767, -122.35530031200001],
#  [47.596662187, -122.31805490100001],
#  [47.623929893, -122.356714541],
#  [47.668674212, -122.38104184299999]]

# %%
crime_clusters=folium.Map(location=[crime.Latitude.mean(),crime.Longitude.mean()],
                      zoom_start=11,tiles='OpenStreetMap')
plugins.MarkerCluster(locationlist).add_to(crime_clusters)
plugins.ScrollZoomToggler().add_to(crime_clusters)
crime_clusters.save(os.path.join('Maps/', 'crime_clusters.html'))
crime_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
seattle_geo = '/Users/steeznation/Flatiron/Module05/capstone/seattle-boundaries-data/data/spd-beats.geojson'

seattle_coords = (47.6062, -122.3321)

# %%
zones = crime_df[['Zone/Beat', 'District/Sector', 'Latitude', 'Longitude']]
zones.head()
# Out:
#   Zone/Beat District/Sector   Latitude   Longitude
# 0        M2               M  47.610975 -122.338147
# 1        Q1               Q  47.658325 -122.404613
# 2        M2               M  47.613551 -122.342843
# 3        D1               D  47.625401 -122.341847
# 4        D1               D  47.627425 -122.339709

# %%
zones.dropna(inplace=True)

# %%
print(zones['District/Sector'].unique())
zlist = list(zones['District/Sector'].unique())
# Out:
# ['M' 'Q' 'D' 'R' 'U' 'K' 'N' 'S' 'F' 'J' 'L' 'W' 'E' 'C' 'G' 'B' 'O' '99'
#  'H']

# %%
zones[zones['Zone/Beat'] == 'M2'].head()
# Out:
#    Zone/Beat District/Sector   Latitude   Longitude
# 0         M2               M  47.610975 -122.338147
# 2         M2               M  47.613551 -122.342843
# 37        M2               M  47.613343 -122.338524
# 78        M2               M  47.611706 -122.338048
# 92        M2               M  47.612887 -122.343703

# %%
zones.isna().sum()
# Out:
# Zone/Beat          0
# District/Sector    0
# Latitude           0
# Longitude          0
# dtype: int64

# %%
crimes_dict.keys()
# Out:
# dict_keys(['M', 'Q', 'D', 'R', 'U', 'K', 'N', 'S', 'F', 'J', 'L', 'W', 'E', 'C', 'G', 'B', 'O', '99', 'H'])

# %%
z_dict = {}
for z in zlist:
    df = zones.loc[zones['District/Sector'] == z]
    z_dict[z] = {}
    z_dict[z]['Lat'] = (df['Latitude'].mean())
    z_dict[z]['Long'] = (df['Longitude'].mean())
    z_dict[z]["Top 5"] = crimes_dict[z]["top_5"]

# %%
crimes_dict
# Out:
# {'M': {'top_5': 'Disturbances = 14.62 percent of Crime, Traffic Related Calls = 11.656 percent of Crime, Liquor Violations = 11.359 percent of Crime, Suspicious Circumstances = 9.168 percent of Crime, Shoplifting = 6.268 percent of Crime, '},
#  'Q': {'top_5': 'Traffic Related Calls = 21.557 percent of Crime, Suspicious Circumstances = 14.751 percent of Crime, Disturbances = 11.935 percent of Crime, Car Prowl = 4.642 percent of Crime, False Alarms = 4.214 percent of Crime, '},
#  'D': {'top_5': 'Traffic Related Calls = 17.376 percent of Crime, Disturbances = 13.992 percent of Crime, Suspicious Circumstances = 12.059 percent of Crime, Liquor Violations = 5.786 percent of Crime, Car Prowl = 4.686 percent of Crime, '},
#  'R': {'top_5': 'Traffic Related Calls = 21.72 percent of Crime, Suspicious Circumstances = 18.362 percent of Crime, Disturbances = 11.712 percent of Crime, False Alarms = 4.243 percent of Crime, Motor Vehicle Collision Investigation = 3.864 percent of Crime, '},
#  'U': {'top_5': 'Disturbances = 17.26 percent of Crime, Suspicious Circumstances = 16.625 percent of Crime, Traffic Related Calls = 15.218 percent of Crime, Burglary = 4.483 percent of Crime, Car Prowl = 3.664 percent of Crime, '},
#  'K': {'top_5': 'Liquor Violations = 21.465 percent of Crime, Disturbances = 13.383 percent of Crime, Traffic Related Calls = 12.122 percent of Crime, Suspicious Circumstances = 8.872 percent of Crime, Narcotics Complaints = 4.608 percent of Crime, '},
#  'N': {'top_5': 'Suspicious Circumstances = 20.074 percent of Crime, Traffic Related Calls = 14.838 percent of Crime, Disturbances = 13.728 percent of Crime, Other Property = 3.4 percent of Crime, Car Prowl = 3.384 percent of Crime, '},
#  'S': {'top_5': 'Traffic Related Calls = 20.327 percent of Crime, Suspicious Circumstances = 18.863 percent of Crime, Disturbances = 13.249 percent of Crime, Auto Thefts = 3.768 percent of Crime, Burglary = 3.652 percent of Crime, '},
#  'F': {'top_5': 'Suspicious Circumstances = 20.41 percent of Crime, Disturbances = 15.936 percent of Crime, Traffic Related Calls = 15.014 percent of Crime, Auto Thefts = 3.811 percent of Crime, Burglary = 3.57 percent of Crime, '},
#  'J': {'top_5': 'Traffic Related Calls = 22.629 percent of Crime, Suspicious Circumstances = 17.553 percent of Crime, Disturbances = 12.523 percent of Crime, Car Prowl = 4.673 percent of Crime, Burglary = 3.762 percent of Crime, '},
#  'L': {'top_5': 'Suspicious Circumstances = 19.72 percent of Crime, Disturbances = 14.93 percent of Crime, Traffic Related Calls = 14.315 percent of Crime, False Alarms = 4.436 percent of Crime, Burglary = 4.288 percent of Crime, '},
#  'W': {'top_5': 'Traffic Related Calls = 21.519 percent of Crime, Suspicious Circumstances = 17.574 percent of Crime, Disturbances = 13.085 percent of Crime, False Alarms = 4.564 percent of Crime, Burglary = 3.459 percent of Crime, '},
#  'E': {'top_5': 'Traffic Related Calls = 18.071 percent of Crime, Disturbances = 16.62 percent of Crime, Suspicious Circumstances = 13.803 percent of Crime, Liquor Violations = 8.374 percent of Crime, Trespass = 5.999 percent of Crime, '},
#  'C': {'top_5': 'Traffic Related Calls = 23.447 percent of Crime, Suspicious Circumstances = 16.635 percent of Crime, Disturbances = 12.725 percent of Crime, False Alarms = 4.687 percent of Crime, Car Prowl = 3.568 percent of Crime, '},
#  'G': {'top_5': 'Traffic Related Calls = 21.113 percent of Crime, Suspicious Circumstances = 15.697 percent of Crime, Disturbances = 15.158 percent of Crime, Shoplifting = 4.435 percent of Crime, Car Prowl = 3.363 percent of Crime, '},
#  'B': {'top_5': 'Traffic Related Calls = 19.736 percent of Crime, Suspicious Circumstances = 18.252 percent of Crime, Disturbances = 13.883 percent of Crime, Burglary = 3.932 percent of Crime, Car Prowl = 3.724 percent of Crime, '},
#  'O': {'top_5': 'Traffic Related Calls = 24.335 percent of Crime, Suspicious Circumstances = 13.996 percent of Crime, Disturbances = 9.413 percent of Crime, Liquor Violations = 8.027 percent of Crime, Accident Investigation = 4.188 percent of Crime, '},
#  '99': {'top_5': 'Traffic Related Calls = 51.887 percent of Crime, Suspicious Circumstances = 9.434 percent of Crime, Arrest = 5.66 percent of Crime, Disturbances = 5.66 percent of Crime, Person Down/Injury = 2.83 percent of Crime, '},
#  'H': {'top_5': 'Harbor Calls = 55.556 percent of Crime, Traffic Related Calls = 22.222 percent of Crime, Property Damage = 11.111 percent of Crime, Person Down/Injury = 11.111 percent of Crime, '}}

# %%
m = folium.Map(location=seattle_coords, zoom_start=11)
for k, v in (z_dict.items()):
    folium.Marker([v['Lat'], v['Long']], popup=folium.Popup(v['Top 5'], max_width=150), tooltip=k).add_to(m)
plugins.ScrollZoomToggler().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# definition of the boundaries in the map
district_geo = seattle_geo
  
# calculating total number of incidents per district
crimedata = pd.DataFrame(crime_df['Zone/Beat'].value_counts().astype(float))
crimedata.to_json('crimeagg.json')
crimedata = crimedata.reset_index()
crimedata.columns = ['Beat', 'Number']

m = folium.Map(location=seattle_coords, zoom_start=11)
folium.Choropleth(geo_data=seattle_geo,
                  data=crimedata,
                  columns=['Beat', 'Number'],
                  key_on='feature.properties.name',
                  fill_color='YlGnBu',
                  fill_opacity=0.8,
                  line_opacity=0.2,
                  bins=9,
                  name='Incidents per Beat',
                  legend_name='Incidents per Beat',
                  highlight=True).add_to(m)

for k, v in (z_dict.items()):
    # print(k, list([v['Lat'], v['Long']]))
    folium.Marker([v['Lat'], v['Long']], popup=folium.Popup(v["Top 5"], max_width=150), 
                  tooltip=("District: "+str(k))).add_to(m)
plugins.MarkerCluster(locationlist, name='Crime Clusters').add_to(m)
folium.LayerControl().add_to(m)
plugins.ScrollZoomToggler().add_to(m)

m.save(os.path.join('Maps/', 'crime_districts.html'))
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
len(crime_df)
# Out:
# 1415994

# %%
locations1 = crime_df[['Latitude', 'Longitude']][:50000]
locationlist1 = locations1.values.tolist()
print(len(locationlist1))
locationlist1[:5]
# Out:
# 50000
# [[47.610975163, -122.33814674799999],
#  [47.65832489899999, -122.404612874],
#  [47.613551471, -122.342843234],
#  [47.625401388, -122.341846999],
#  [47.627424837, -122.339708605]]

# %%
# %%time
# definition of the boundaries in the map
district_geo = seattle_geo

# calculating total number of incidents per district
crimedata = pd.DataFrame(crime_df['Zone/Beat'].value_counts().astype(float))
crimedata.to_json('crimeagg.json')
crimedata = crimedata.reset_index()
crimedata.columns = ['Beat', 'Number']

m = folium.Map(location=seattle_coords, zoom_start=11)

folium.Choropleth(geo_data=seattle_geo,
                  data=crimedata,
                  columns=['Beat', 'Number'],
                  key_on='feature.properties.name',
                  fill_color='YlGn',
                  fill_opacity=0.8,
                  line_opacity=0.2,
                  bins=9,
                  name='Incidents per Beat',
                  legend_name='Incidents per Beat',
                  highlight=True).add_to(m)

fg = folium.FeatureGroup(name='All Groups')
m.add_child(fg)
g1 = plugins.FeatureGroupSubGroup(fg, 'Districts')
m.add_child(g1)
g2 = plugins.FeatureGroupSubGroup(fg, 'Clusters')
m.add_child(g2)

for k, v in (z_dict.items()):
    folium.Marker([v['Lat'], v['Long']], popup=folium.Popup(v["Top 5"], max_width=200), 
                  tooltip=("District: "+str(k))).add_to(g1)
folium.TileLayer(tiles="OpenStreetMap", name='Open Street Map').add_to(m)
folium.TileLayer(tiles="Stamen Terrain", name='Stamen Terrain').add_to(m)
folium.TileLayer(tiles="Mapbox Bright", name='Mapbox Bright').add_to(m)

layers = folium.LayerControl().add_to(m)
plugins.ScrollZoomToggler().add_to(m)

plugins.MarkerCluster(locationlist1, name='Crime Clusters').add_to(g2)

m.save(os.path.join('Maps/', 'final_crime.html'))
# Out:
# CPU times: user 24.7 s, sys: 883 ms, total: 25.6 s
# Wall time: 26.5 s
